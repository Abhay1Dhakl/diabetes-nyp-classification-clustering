# %% [markdown]
# ## Import Models

# %%
import pandas as pd

# %%
# Load the CSV file into a DataFrame
RAW_PATH = "../data/raw/diabetes.csv"
PROCESSED_PATH = "../data/processed/diabetes_clean.csv"

df = pd.read_csv(RAW_PATH)

# quick check of the data
print("shape of the data:", df.shape)
print("columns in the data:", df.columns)
print("data types of the columns:", df.dtypes)

display(df.head())
# Out:
# shape of the data: (1000, 14)
# columns in the data: Index(['ID', 'No_Pation', 'Gender', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG',
#        'HDL', 'LDL', 'VLDL', 'BMI', 'CLASS'],
#       dtype='str')
# data types of the columns: ID             int64
# No_Pation      int64
# Gender           str
# AGE            int64
# Urea         float64
# Cr             int64
# HbA1c        float64
# Chol         float64
# TG           float64
# HDL          float64
# LDL          float64
# VLDL         float64
# BMI          float64
# CLASS            str
# dtype: object
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# ...

# %%
# trim columns for better readability
df.columns = df.columns.str.strip()

# clean labels
df["CLASS"] = df["CLASS"].astype(str).str.strip()
df["Gender"] = df["Gender"].astype(str).str.strip().str.upper()

print("Class Values:", df["CLASS"].unique())
print("CLASS ounts:\n", df["CLASS"].value_counts())

print("Gender Values:\n", df["Gender"].unique())
print("Gender Counts:\n", df["Gender"].value_counts())
# Out:
# Class Values: <StringArray>
# ['N', 'P', 'Y']
# Length: 3, dtype: str
# CLASS ounts:
#  CLASS
# Y    844
# N    103
# P     53
# Name: count, dtype: int64
# Gender Values:
#  <StringArray>
# ['F', 'M']
# Length: 2, dtype: str
# Gender Counts:
#  Gender
# M    565
# F    435
# Name: count, dtype: int64

# %%
print("Missing values per column:\n", df.isna().sum().sort_values(ascending=False))
display(df.describe(include="all"))
# Out:
# Missing values per column:
#  ID           0
# No_Pation    0
# Gender       0
# AGE          0
# Urea         0
# Cr           0
# HbA1c        0
# Chol         0
# TG           0
# HDL          0
# LDL          0
# VLDL         0
# BMI          0
# CLASS        0
# dtype: int64
#                  ID     No_Pation Gender          AGE         Urea  \
# count   1000.000000  1.000000e+03   1000  1000.000000  1000.000000
# unique          NaN           NaN      2          NaN          NaN
# top             NaN           NaN      M          NaN          NaN
# freq            NaN           NaN    565          NaN          NaN
# mean     340.500000  2.705514e+05    NaN    53.528000     5.124743
# std      240.397673  3.380758e+06    NaN     8.799241     2.935165
# min        1.000000  1.230000e+02    NaN    20.000000     0.500000
# 25%      125.750000  2.406375e+04    NaN    51.000000     3.700000
# 50%      300.500000  3.439550e+04    NaN    55.000000     4.600000
# ...

# %%
id_cols = [c for c in ["ID", "No_Pation"] if c in df.columns]
X_df = df.drop(columns=id_cols, errors="ignore")
print("Dropped ID columns:", id_cols)
print("Remaining columns:", list(X_df.columns))
# Out:
# Dropped ID columns: ['ID', 'No_Pation']
# Remaining columns: ['Gender', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG', 'HDL', 'LDL', 'VLDL', 'BMI', 'CLASS']

# %%
df.to_csv(PROCESSED_PATH, index=False)
print("Saved:", PROCESSED_PATH)
# Out:
# Saved: ../data/processed/diabetes_clean.csv
